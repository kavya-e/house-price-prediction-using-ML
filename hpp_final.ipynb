# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('train.csv')

# %%
data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
#        'GarageYrBlt', 'GarageFinish', 'GarageCars', 'GarageArea', 'GarageQual',
# ...

# %%
data=data[["Id","MSZoning","Utilities","Neighborhood","Condition1","BldgType","HouseStyle","OverallQual","YearBuilt","Foundation","GrLivArea","TotRmsAbvGrd","GarageType","GarageArea","FullBath","HalfBath","BedroomAbvGr"]]

# %%
data.head()
# Out:
#    Id MSZoning Utilities Neighborhood Condition1 BldgType HouseStyle  \
# 0   1       RL    AllPub      CollgCr       Norm     1Fam     2Story
# 1   2       RL    AllPub      Veenker      Feedr     1Fam     1Story
# 2   3       RL    AllPub      CollgCr       Norm     1Fam     2Story
# 3   4       RL    AllPub      Crawfor       Norm     1Fam     2Story
# 4   5       RL    AllPub      NoRidge       Norm     1Fam     2Story
#
#    OverallQual  YearBuilt Foundation  GrLivArea  TotRmsAbvGrd GarageType  \
# 0            7       2003      PConc       1710             8     Attchd
# 1            6       1976     CBlock       1262             6     Attchd
# 2            7       2001      PConc       1786             6     Attchd
# 3            7       1915     BrkTil       1717             7     Detchd
# 4            8       2000      PConc       2198             9     Attchd
#
#    GarageArea  FullBath  HalfBath  BedroomAbvGr
# 0         548         2         1             3
# ...

# %%
data.columns
# Out:
# Index(['Id', 'MSZoning', 'Utilities', 'Neighborhood', 'Condition1', 'BldgType',
#        'HouseStyle', 'OverallQual', 'YearBuilt', 'Foundation', 'GrLivArea',
#        'TotRmsAbvGrd', 'GarageType', 'GarageArea', 'FullBath', 'HalfBath',
#        'BedroomAbvGr'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Id               int64
# MSZoning        object
# Utilities       object
# Neighborhood    object
# Condition1      object
# BldgType        object
# HouseStyle      object
# OverallQual      int64
# YearBuilt        int64
# Foundation      object
# GrLivArea        int64
# TotRmsAbvGrd     int64
# GarageType      object
# GarageArea       int64
# FullBath         int64
# HalfBath         int64
# BedroomAbvGr     int64
# dtype: object

# %%
data=data.drop("Id",axis=1)

# %%
data.head()
# Out:
#   MSZoning Utilities Neighborhood Condition1 BldgType HouseStyle  OverallQual  \
# 0       RL    AllPub      CollgCr       Norm     1Fam     2Story            7
# 1       RL    AllPub      Veenker      Feedr     1Fam     1Story            6
# 2       RL    AllPub      CollgCr       Norm     1Fam     2Story            7
# 3       RL    AllPub      Crawfor       Norm     1Fam     2Story            7
# 4       RL    AllPub      NoRidge       Norm     1Fam     2Story            8
#
#    YearBuilt Foundation  GrLivArea  TotRmsAbvGrd GarageType  GarageArea  \
# 0       2003      PConc       1710             8     Attchd         548
# 1       1976     CBlock       1262             6     Attchd         460
# 2       2001      PConc       1786             6     Attchd         608
# 3       1915     BrkTil       1717             7     Detchd         642
# 4       2000      PConc       2198             9     Attchd         836
#
#    FullBath  HalfBath  BedroomAbvGr
# ...

# %%
data.dtypes
# Out:
# MSZoning        object
# Utilities       object
# Neighborhood    object
# Condition1      object
# BldgType        object
# HouseStyle      object
# OverallQual      int64
# YearBuilt        int64
# Foundation      object
# GrLivArea        int64
# TotRmsAbvGrd     int64
# GarageType      object
# GarageArea       int64
# FullBath         int64
# HalfBath         int64
# BedroomAbvGr     int64
# dtype: object

# %%
data["MSZoning"].value_counts()
# Out:
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64

# %%
data["Utilities"].value_counts()
# Out:
# AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64

# %%
columns=data.columns

# %%
print(columns)
print(type(columns))
# Out:
# Index(['MSZoning', 'Utilities', 'Neighborhood', 'Condition1', 'BldgType',
#        'HouseStyle', 'OverallQual', 'YearBuilt', 'Foundation', 'GrLivArea',
#        'TotRmsAbvGrd', 'GarageType', 'GarageArea', 'FullBath', 'HalfBath',
#        'BedroomAbvGr'],
#       dtype='object')
# <class 'pandas.core.indexes.base.Index'>

# %%
for i in columns:
    print("*******")
    print(i)
    col_name=i
    print(data[col_name].value_counts())
# Out:
# *******
# MSZoning
# RL         1151
# RM          218
# FV           65
# RH           16
# C (all)      10
# Name: MSZoning, dtype: int64
# *******
# Utilities
# AllPub    1459
# NoSeWa       1
# Name: Utilities, dtype: int64
# *******
# Neighborhood
# NAmes      225
# CollgCr    150
# OldTown    113
# Edwards    100
# Somerst     86
# Gilbert     79
# NridgHt     77
# Sawyer      74
# NWAmes      73
# SawyerW     59
# BrkSide     58
# Crawfor     51
# Mitchel     49
# NoRidge     41
# Timber      38
# IDOTRR      37
# ClearCr     28
# StoneBr     25
# SWISU       25
# MeadowV     17
# Blmngtn     17
# BrDale      16
# Veenker     11
# NPkVill      9
# Blueste      2
# Name: Neighborhood, dtype: int64
# *******
# Condition1
# Norm      1260
# Feedr       81
# Artery      48
# RRAn        26
# PosN        19
# RRAe        11
# PosA         8
# RRNn         5
# RRNe         2
# Name: Condition1, dtype: int64
# *******
# BldgType
# 1Fam      1220
# TwnhsE     114
# Duplex      52
# ...

# %%
data["Age"]=2022-data["YearBuilt"]

# %%
data["Age"].value_counts()
# Out:
# 16     67
# 17     64
# 18     54
# 15     49
# 19     45
#        ..
# 147     1
# 111     1
# 105     1
# 150     1
# 117     1
# Name: Age, Length: 112, dtype: int64

# %%
data=data.drop("YearBuilt",axis=1)

# %%
data.head()
# Out:
#   MSZoning Utilities Neighborhood Condition1 BldgType HouseStyle  OverallQual  \
# 0       RL    AllPub      CollgCr       Norm     1Fam     2Story            7
# 1       RL    AllPub      Veenker      Feedr     1Fam     1Story            6
# 2       RL    AllPub      CollgCr       Norm     1Fam     2Story            7
# 3       RL    AllPub      Crawfor       Norm     1Fam     2Story            7
# 4       RL    AllPub      NoRidge       Norm     1Fam     2Story            8
#
#   Foundation  GrLivArea  TotRmsAbvGrd GarageType  GarageArea  FullBath  \
# 0      PConc       1710             8     Attchd         548         2
# 1     CBlock       1262             6     Attchd         460         2
# 2      PConc       1786             6     Attchd         608         2
# 3     BrkTil       1717             7     Detchd         642         1
# 4      PConc       2198             9     Attchd         836         2
#
#    HalfBath  BedroomAbvGr  Age
# 0         1             3   19
# ...

# %%
data.dtypes
# Out:
# MSZoning        object
# Utilities       object
# Neighborhood    object
# Condition1      object
# BldgType        object
# HouseStyle      object
# OverallQual      int64
# Foundation      object
# GrLivArea        int64
# TotRmsAbvGrd     int64
# GarageType      object
# GarageArea       int64
# FullBath         int64
# HalfBath         int64
# BedroomAbvGr     int64
# Age              int64
# dtype: object

# %%
data.shape
# Out:
# (1460, 16)

# %%
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline
from sklearn.metrics import r2_score

# %%
X_train=data
Y_train=pd.read_csv("train.csv")["SalePrice"]

# %%
X_train.shape
# Out:
# (1460, 16)

# %%
Y_train.shape
# Out:
# (1460,)

# %%
data_test=pd.read_csv("test.csv")
data_test=data_test[["Id","MSZoning","Utilities","Neighborhood","Condition1","BldgType","HouseStyle","OverallQual","YearBuilt","Foundation","GrLivArea","TotRmsAbvGrd","GarageType","GarageArea","FullBath","HalfBath","BedroomAbvGr"]]
data_test["Age"]=2022-data_test["YearBuilt"]
data_test.drop("YearBuilt",axis=1)
# Out:
#         Id MSZoning Utilities Neighborhood Condition1 BldgType HouseStyle  \
# 0     1461       RH    AllPub        NAmes      Feedr     1Fam     1Story
# 1     1462       RL    AllPub        NAmes       Norm     1Fam     1Story
# 2     1463       RL    AllPub      Gilbert       Norm     1Fam     2Story
# 3     1464       RL    AllPub      Gilbert       Norm     1Fam     2Story
# 4     1465       RL    AllPub      StoneBr       Norm   TwnhsE     1Story
# ...    ...      ...       ...          ...        ...      ...        ...
# 1454  2915       RM    AllPub      MeadowV       Norm    Twnhs     2Story
# 1455  2916       RM    AllPub      MeadowV       Norm   TwnhsE     2Story
# 1456  2917       RL    AllPub      Mitchel       Norm     1Fam     1Story
# 1457  2918       RL    AllPub      Mitchel       Norm     1Fam     SFoyer
# 1458  2919       RL    AllPub      Mitchel       Norm     1Fam     2Story
#
#       OverallQual Foundation  GrLivArea  TotRmsAbvGrd GarageType  GarageArea  \
# ...

# %%
column_trans=make_column_transformer((OneHotEncoder(sparse=False),["MSZoning","Utilities","Neighborhood","Condition1","BldgType","HouseStyle","Foundation","GarageType"]),remainder='passthrough')

# %%
scaler=StandardScaler()

# %%
lr=LinearRegression(normalize=True)

# %%
pipe=make_pipeline(column_trans,scaler,lr)

# %%
pipe.fit(X_train,Y_train)
# Out:
# c:\users\91955\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_base.py:141: FutureWarning: 'normalize' was deprecated in version 1.0 and will be removed in 1.2.
# If you wish to scale the data, use Pipeline with a StandardScaler in a preprocessing stage. To reproduce the previous behavior:
#
# from sklearn.pipeline import make_pipeline
#
# model = make_pipeline(StandardScaler(with_mean=False), LinearRegression())
#
# If you wish to pass a sample_weight parameter, you need to pass it as a fit parameter to each step of the pipeline as follows:
#
# kwargs = {s[0] + '__sample_weight': sample_weight for s in model.steps}
# model.fit(X, y, **kwargs)
#
#
#   warnings.warn(
# Pipeline(steps=[('columntransformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehotencoder',
#                                                   OneHotEncoder(sparse=False),
# ...

# %%
X_test=pd.read_csv("test.csv")
X_test=X_test[["Id","MSZoning","Utilities","Neighborhood","Condition1","BldgType","HouseStyle","OverallQual","YearBuilt","Foundation","GrLivArea","TotRmsAbvGrd","GarageType","GarageArea","FullBath","HalfBath","BedroomAbvGr"]]

X_test=X_test.drop("Id",axis=1)
#y_pred_lr=pipe.predict(X_test)

# %%
X_test["Age"]=2022-X_test["YearBuilt"]

# %%
X_test=X_test.drop("YearBuilt",axis=1)

# %%
X_test.head()
# Out:
#   MSZoning Utilities Neighborhood Condition1 BldgType HouseStyle  OverallQual  \
# 0       RH    AllPub        NAmes      Feedr     1Fam     1Story            5
# 1       RL    AllPub        NAmes       Norm     1Fam     1Story            6
# 2       RL    AllPub      Gilbert       Norm     1Fam     2Story            5
# 3       RL    AllPub      Gilbert       Norm     1Fam     2Story            6
# 4       RL    AllPub      StoneBr       Norm   TwnhsE     1Story            8
#
#   Foundation  GrLivArea  TotRmsAbvGrd GarageType  GarageArea  FullBath  \
# 0     CBlock        896             5     Attchd       730.0         1
# 1     CBlock       1329             6     Attchd       312.0         1
# 2      PConc       1629             6     Attchd       482.0         2
# 3      PConc       1604             7     Attchd       470.0         2
# 4      PConc       1280             5     Attchd       506.0         2
#
#    HalfBath  BedroomAbvGr  Age
# 0         0             2   61
# ...

# %%
X_test.shape
# Out:
# (1459, 16)

# %%
Null_check=X_test.isnull()

# %%
Null_check
# Out:
#       MSZoning  Utilities  Neighborhood  Condition1  BldgType  HouseStyle  \
# 0        False      False         False       False     False       False
# 1        False      False         False       False     False       False
# 2        False      False         False       False     False       False
# 3        False      False         False       False     False       False
# 4        False      False         False       False     False       False
# ...        ...        ...           ...         ...       ...         ...
# 1454     False      False         False       False     False       False
# 1455     False      False         False       False     False       False
# 1456     False      False         False       False     False       False
# 1457     False      False         False       False     False       False
# 1458     False      False         False       False     False       False
#
#       OverallQual  Foundation  GrLivArea  TotRmsAbvGrd  GarageType  \
# ...

# %%
X_test=X_test.dropna()

# %%
X_test.shape
# Out:
# (1377, 16)

# %%
y_pred_lr=pipe.predict(X_test)

# %%
y_pred_lr
# Out:
# array([111444.41407465, 163399.40393966, 163632.10081181, ...,
#         66793.4026843 , 141176.34186129, 231476.58333888])

# %%
import pickle

# %%
pickle.dump(pipe,open('LinearModel.pkl','wb'))
